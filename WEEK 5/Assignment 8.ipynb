# %%
# creating dataset
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'First Name': ['Aryan', 'Rohan', 'Riya', 'Yash', 'Siddhant', ],
 'Last Name': ['Singh', 'Agarwal', 'Shah', 'Bhatia', 'Khanna'],
 'Type': ['Full-time Employee', 'Intern', 'Full-time Employee',
 'Part-time Employee', 'Full-time Employee'],
 'Department': ['Administration', 'Technical', 'Administration',
 'Technical', 'Management'],
 'YoE': [2, 3, 5, 7, 6],
 'Salary': [20000, 5000, 10000, 10000, 20000]})

df
# Out:
#   First Name Last Name                Type      Department  YoE  Salary
# 0      Aryan     Singh  Full-time Employee  Administration    2   20000
# 1      Rohan   Agarwal              Intern       Technical    3    5000
# 2       Riya      Shah  Full-time Employee  Administration    5   10000
# 3       Yash    Bhatia  Part-time Employee       Technical    7   10000
# 4   Siddhant    Khanna  Full-time Employee      Management    6   20000

# %%
output = pd.pivot_table(data=df,
 index=['Type'],
 columns=['Department'],
 values='Salary',
 aggfunc='mean')
output
# Out:
# Department          Administration  Management  Technical
# Type
# Full-time Employee         15000.0     20000.0        NaN
# Intern                         NaN         NaN     5000.0
# Part-time Employee             NaN         NaN    10000.0

# %% [markdown]
# # I.Pivot table with multiple aggregation functions

# %%
# Pivot table with multiple aggfuncs
output = pd.pivot_table(data=df, index=['Type'],
 values='Salary',
 aggfunc=['sum', 'mean', 'count'])
output
# Out:
#                       sum          mean  count
#                    Salary        Salary Salary
# Type
# Full-time Employee  50000  16666.666667      3
# Intern               5000   5000.000000      1
# Part-time Employee  10000  10000.000000      1

# %% [markdown]
# # II.Calculating row and column grand totals in pivot_table

# %%
# Calculate row and column totals (margins)
output = pd.pivot_table(data=df, index=['Type'],
 values='Salary',
 aggfunc=['sum', 'mean', 'count'],
 margins=True,
 margins_name='Grand Total')
output
# Out:
#                       sum          mean  count
#                    Salary        Salary Salary
# Type
# Full-time Employee  50000  16666.666667      3
# Intern               5000   5000.000000      1
# Part-time Employee  10000  10000.000000      1
# Grand Total         65000  13000.000000      5

# %% [markdown]
# # III.Aggregating for multiple features in pivot table

# %%
# Aggregating for multiple features
output = pd.pivot_table(data=df, index='Type', values=['Salary', 'YoE'],
 columns=['Department'],
 aggfunc={'Salary': np.sum, 'YoE': np.mean})
output
# Out:
#                            Salary                                 YoE  \
# Department         Administration Management Technical Administration
# Type
# Full-time Employee        30000.0    20000.0       NaN            3.5
# Intern                        NaN        NaN    5000.0            NaN
# Part-time Employee            NaN        NaN   10000.0            NaN
#
#
# Department         Management Technical
# Type
# Full-time Employee        6.0       NaN
# Intern                    NaN       3.0
# Part-time Employee        NaN       7.0

# %% [markdown]
# # IV.Replacing missing values

# %%
# Replacing missing values
output = pd.pivot_table(data=df, index='Type', values=['Salary', 'YoE'],
                        columns=['Department'],
                        aggfunc={'Salary': np.sum, 'YoE': np.mean},
                        fill_value='Not applicable')
output
# Out:
#                             Salary                                  \
# Department          Administration      Management       Technical
# Type
# Full-time Employee         30000.0         20000.0  Not applicable
# Intern              Not applicable  Not applicable          5000.0
# Part-time Employee  Not applicable  Not applicable         10000.0
#
#                                YoE
# Department          Administration      Management       Technical
# Type
# Full-time Employee             3.5             6.0  Not applicable
# Intern              Not applicable  Not applicable             3.0
# Part-time Employee  Not applicable  Not applicable             7.0

# %% [markdown]
# # V.Multi-level index pivot tables

# %%
# Passing Type and then Last Name as indices
output = pd.pivot_table(data=df, index=['Type', 'Last Name'],
 values='Salary',
 aggfunc=['sum', 'mean', 'count'],
 margins=True,
 margins_name='Grand Total')
output
# Out:
#                                 sum   mean  count
#                              Salary Salary Salary
# Type               Last Name
# Full-time Employee Khanna     20000  20000      1
#                    Shah       10000  10000      1
#                    Singh      20000  20000      1
# Intern             Agarwal     5000   5000      1
# Part-time Employee Bhatia     10000  10000      1
# Grand Total                   65000  13000      5

# %% [markdown]
# # VI.Ordering multi-level index pivot tables

# %%
# Passing Last Name and then Type as indices
output = pd.pivot_table(data=df, index=['Last Name', 'Type'],
 values='Salary',
 aggfunc=['sum', 'mean', 'count'],
 margins=True,
 margins_name='Grand Total')
output
# Out:
#                                   sum   mean  count
#                                Salary Salary Salary
# Last Name   Type
# Agarwal     Intern               5000   5000      1
# Bhatia      Part-time Employee  10000  10000      1
# Khanna      Full-time Employee  20000  20000      1
# Shah        Full-time Employee  10000  10000      1
# Singh       Full-time Employee  20000  20000      1
# Grand Total                     65000  13000      5

# %%
# Passing Type and then Last Name as indices
type_pivot_table = pd.pivot_table(data=df,
 index=['Type', 'Last Name'],
 values='Salary',
 aggfunc=['sum', 'mean', 'count'],
 margins=True,
 margins_name='Grand Total')
type_pivot_table
# Out:
#                                 sum   mean  count
#                              Salary Salary Salary
# Type               Last Name
# Full-time Employee Khanna     20000  20000      1
#                    Shah       10000  10000      1
#                    Singh      20000  20000      1
# Intern             Agarwal     5000   5000      1
# Part-time Employee Bhatia     10000  10000      1
# Grand Total                   65000  13000      5

# %% [markdown]
# # GroupBy function

# %%
# Pivot tables
output = pd.pivot_table(data=df,
 index=['Type'],
 values='Salary')
print(output)
# Out:
#                           Salary
# Type
# Full-time Employee  16666.666667
# Intern               5000.000000
# Part-time Employee  10000.000000
