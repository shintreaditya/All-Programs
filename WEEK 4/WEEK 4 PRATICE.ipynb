# %%
import numpy as np
import pandas as pd
rainfall_df=pd.read_csv('rainfall.csv')
rainfall_df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
#Statistical Feature
rainfall_df.describe()
# Out:
#               JAN         FEB         MAR         APR         MAY  \
# count  641.000000  641.000000  641.000000  641.000000  641.000000
# mean    18.355070   20.984399   30.034789   45.543214   81.535101
# std     21.082806   27.729596   45.451082   71.556279  111.960390
# min      0.000000    0.000000    0.000000    0.000000    0.900000
# 25%      6.900000    7.000000    7.000000    5.000000   12.100000
# 50%     13.300000   12.300000   12.700000   15.100000   33.900000
# 75%     19.200000   24.100000   33.200000   48.300000   91.900000
# max    144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP         OCT  \
# count   641.000000   641.000000   641.000000  641.000000  641.000000
# mean    196.007332   326.033697   291.152262  194.609048   90.446334
# std     196.556284   221.364643   152.647325   99.830540   74.990685
# min       3.800000    11.600000    14.100000    8.600000    3.100000
# ...

# %%
string_rainfall_df=pd.read_csv('rainfall.csv',index_col=0)
string_rainfall_df
# Out:
#                                    DISTRICT    JAN   FEB    MAR    APR    MAY  \
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0  358.5
# ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5  374.4
# ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4  343.6
# ARUNACHAL PRADESH                     LOHIT   42.2  80.8  176.4  358.5  306.4
# ARUNACHAL PRADESH                EAST SIANG   33.3  79.5  105.9  216.5  323.0
# ...                                     ...    ...   ...    ...    ...    ...
# KERALA                               IDUKKI   13.4  22.1   43.6  150.4  232.6
# KERALA                             KASARGOD    2.3   1.0    8.4   46.9  217.6
# KERALA                       PATHANAMTHITTA   19.8  45.2   73.9  184.9  294.7
# KERALA                              WAYANAD    4.8   8.3   17.5   83.3  174.6
# LAKSHADWEEP                     LAKSHADWEEP   20.8  14.7   11.8   48.9  171.7
#
# ...

# %%
rainfall_df.isnull()
# Out:
#      STATE_UT_NAME  DISTRICT    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 0            False     False  False  False  False  False  False  False  False
# 1            False     False  False  False  False  False  False  False  False
# 2            False     False  False  False  False  False  False  False  False
# 3            False     False  False  False  False  False  False  False  False
# 4            False     False  False  False  False  False  False  False  False
# ..             ...       ...    ...    ...    ...    ...    ...    ...    ...
# 636          False     False  False  False  False  False  False  False  False
# 637          False     False  False  False  False  False  False  False  False
# 638          False     False  False  False  False  False  False  False  False
# 639          False     False  False  False  False  False  False  False  False
# 640          False     False  False  False  False  False  False  False  False
#
# ...

# %%
rainfall_df.notna()
# Out:
#      STATE_UT_NAME  DISTRICT   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG  \
# 0             True      True  True  True  True  True  True  True  True  True
# 1             True      True  True  True  True  True  True  True  True  True
# 2             True      True  True  True  True  True  True  True  True  True
# 3             True      True  True  True  True  True  True  True  True  True
# 4             True      True  True  True  True  True  True  True  True  True
# ..             ...       ...   ...   ...   ...   ...   ...   ...   ...   ...
# 636           True      True  True  True  True  True  True  True  True  True
# 637           True      True  True  True  True  True  True  True  True  True
# 638           True      True  True  True  True  True  True  True  True  True
# 639           True      True  True  True  True  True  True  True  True  True
# 640           True      True  True  True  True  True  True  True  True  True
#
# ...

# %%
string_rainfall_df=pd.read_csv('rainfall.csv')
string_rainfall_df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
string_rainfall_df=pd.read_csv('rainfall.csv',index_col=3)
string_rainfall_df
# Out:
#                     STATE_UT_NAME        DISTRICT    JAN    MAR    APR    MAY  \
# FEB
# 57.9  ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3   65.2  117.0  358.5
# 26.0  ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7   18.6   90.5  374.4
# 15.9  ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7    8.6   53.4  343.6
# 80.8            ARUNACHAL PRADESH           LOHIT   42.2  176.4  358.5  306.4
# 79.5            ARUNACHAL PRADESH      EAST SIANG   33.3  105.9  216.5  323.0
# ...                           ...             ...    ...    ...    ...    ...
# 22.1                       KERALA          IDUKKI   13.4   43.6  150.4  232.6
# 1.0                        KERALA        KASARGOD    2.3    8.4   46.9  217.6
# 45.2                       KERALA  PATHANAMTHITTA   19.8   73.9  184.9  294.7
# 8.3                        KERALA         WAYANAD    4.8   17.5   83.3  174.6
# 14.7                  LAKSHADWEEP     LAKSHADWEEP   20.8   11.8   48.9  171.7
#
# ...

# %%
rainfall_df.isnull().sum()
# Out:
# STATE_UT_NAME    0
# DISTRICT         0
# JAN              0
# FEB              0
# MAR              0
# APR              0
# MAY              0
# JUN              0
# JUL              0
# AUG              0
# SEP              0
# OCT              0
# NOV              0
# DEC              0
# ANNUAL           0
# Jan-Feb          0
# Mar-May          0
# Jun-Sep          0
# Oct-Dec          0
# dtype: int64

# %%
rainfall_df.insert(3,column="timess",value="water")
rainfall_df.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN timess   time  times  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  water  water  water
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  water  water  water
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  water  water  water
# 3            ARUNACHAL PRADESH          LOHIT   42.2  water  water  water
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  water  water  water
#
#     FEB    MAR    APR    MAY  ...    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# 0  57.9   65.2  117.0  358.5  ...  271.9  354.8  326.0  315.2  250.9  2805.2
# 1  26.0   18.6   90.5  374.4  ...  423.1  455.6  301.2  275.8  128.3  3015.7
# 2  15.9    8.6   53.4  343.6  ...  460.9  454.8  276.1  198.6  100.0  2913.3
# 3  80.8  176.4  358.5  306.4  ...  427.8  313.6  167.1   34.1   29.8  3043.8
# 4  79.5  105.9  216.5  323.0  ...  711.2  568.0  206.9   29.5   31.7  4034.7
#
#    Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 rainfall_df.insert(3,column="drink",value=123)
#       2 rainfall_df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
#
# ValueError: cannot insert drink, already exists

# %%
import numpy as np
import pandas as pd
rainfall_df=pd.read_csv('rainfall.csv')
rainfall_df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
# Out:
#   Input In [42]
#     del df('time')
#         ^
# SyntaxError: cannot delete function call

# %%
xyz=rainfall_df=pd.read_csv('auto_mpg.csv')
xyz
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
xyz.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
xyz[["horsepower"]].describe()
# Out:
#        horsepower
# count  392.000000
# mean   104.469388
# std     38.491160
# min     46.000000
# 25%     75.000000
# 50%     93.500000
# 75%    126.000000
# max    230.000000

# %%
xyz[["horsepower"]].mode()
# Out:
#    horsepower
# 0       150.0

# %%
newdf=xyz[["horsepower"]].fillna(150,inplace=True)
newdf
# Out:
# C:\Users\GPT BGK\AppData\Local\Temp\ipykernel_8736\3654604793.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf=xyz[["horsepower"]].fillna(150,inplace=True)

# %%
xyz.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
xyz[["horsepower"]]==150
# Out:
#      horsepower
# 0         False
# 1         False
# 2          True
# 3          True
# 4         False
# ..          ...
# 393       False
# 394       False
# 395       False
# 396       False
# 397       False
#
# [398 rows x 1 columns]

# %%
xyz.loc[xyz['horsepower'].isna()]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name]
# Index: []

# %%
g=xyz.groupby('horsepower')
g.get_group(150)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 12   15.0          8         400.0       150.0    3761           9.5
# 32   25.0          4          98.0       150.0    2046          19.0
# 41   14.0          8         318.0       150.0    4096          13.0
# 64   15.0          8         318.0       150.0    4135          13.5
# 66   17.0          8         304.0       150.0    3672          11.5
# 72   15.0          8         304.0       150.0    3892          12.5
# 75   14.0          8         318.0       150.0    4077          14.0
# 86   14.0          8         304.0       150.0    3672          11.5
# 89   15.0          8         318.0       150.0    3777          12.5
# 91   13.0          8         400.0       150.0    4464          12.0
# 93   14.0          8         318.0       150.0    4237          14.5
# ...

# %%
g['name'].agg('ford finto')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 g['name'].agg('ford finto')
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:265, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     262     kwargs = {}
#     264 if isinstance(func, str):
# --> 265     return getattr(self, func)(*args, **kwargs)
#     267 elif isinstance(func, abc.Iterable):
#     268     # Catch instances of lists / tuples
#     269     # but not the class list / tuple itself.
#     270     func = maybe_mangle_lambdas(func)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# ...
