# %% [markdown]
# # 1. Load the data set, print first 5 rows of the data frame, get shape of the data frame, display column names of the data frame

# %%
#Importing librabries
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Load the data
df=pd.read_csv("iris.csv")

# %%
#Print 
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#No of rows and columns
df.shape
# Out:
# (150, 6)

# %% [markdown]
# # 2. Obtain the following output

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#Further inspecting data
def insdata(data):
    return pd.DataFrame({"datatypes":data.dtypes,"No of Levels":data.apply(lambda x:df.max()/df.min())})
insdata(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # 3.Get statistical insights of all and also for the numeric columns and check for duplicates

# %%
df.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
# Perfroming just for numeric columns
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Total no of duplicate values in the data frame
df.duplicated().sum()
# Out:
# 0

# %%
#This shows the actual duplicate rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
#Frequency of each columns
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# # 4. Check for missing values, compute skewness and kurtosis

# %%
#Checking missing values
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Estimating skewness in the data set
df.skew()
# Out:
# C:\Users\GPT BGK\AppData\Local\Temp\ipykernel_2156\150209517.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# Id               0.000000
# SepalLengthCm    0.314911
# SepalWidthCm     0.334053
# PetalLengthCm   -0.274464
# PetalWidthCm    -0.104997
# dtype: float64

# %%
#Estimating kurtosis in the data set
df.kurt()
# Out:
# C:\Users\GPT BGK\AppData\Local\Temp\ipykernel_2156\1162979163.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.kurt()
# Id              -1.200000
# SepalLengthCm   -0.552064
# SepalWidthCm     0.290781
# PetalLengthCm   -1.401921
# PetalWidthCm    -1.339754
# dtype: float64

# %% [markdown]
# # 5. Visualization on target column and relation between variables

# %%
#Visualizing the species count
plt.title('Species count')
sns.countplot(df['Species'])
# Out:
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Species count'}, xlabel='Species', ylabel='count'>

# %%
#Comparison between sepal width and length
plt.title("Comparison between sepal width and length")
sns.scatterplot(df['SepalLengthCm'],df['SepalWidthCm']);
# Out:
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Comparison between sepal width and length n the basis of species
plt.figure(figsize=(16,9))
plt.title('Comparison between sepal width and length n the basis of species')
sns.scatterplot(df['SepalLengthCm'],df['SepalWidthCm'],df['Species'],s=30)
# Out:
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Comparison between sepal width and length n the basis of species'}, xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
#Comparison between petal width and length
plt.title("Comparison between petal width and length")
sns.scatterplot(df['PetalLengthCm'],df['PetalWidthCm'])
# Out:
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Comparison between petal width and length'}, xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
#Comparison between sepal width and length n the basis of species
plt.figure(figsize=(16,9))
plt.title('Comparison between sepal width and length n the basis of species')
sns.scatterplot(df['PetalLengthCm'],df['PetalWidthCm'],hue=df['Species'],s=50)
# Out:
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Comparison between sepal width and length n the basis of species'}, xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
#PLotting a pairplot with hue=Species
sns.pairplot(df,hue="Species",height=3);

# %%
sns.scatterplot(df['PetalWidthCm'],df['SepalLengthCm'])
# Out:
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='SepalLengthCm'>

# %% [markdown]
# # 6. Differentiate numerical and categorical variables

# %%
#Differentiating numerical and categorical variables
catcol=df.dtypes[df.dtypes=='object'].index
print('No of categorical features :',len(catcol),'\n')
print(catcol)
#print('*'*100)
numcol=df.dtypes[df.dtypes!='object'].index
print('No of numerical features:',len(numcol),'\n')
print(numcol)
# Out:
# No of categorical features : 1
#
# Index(['Species'], dtype='object')
# No of numerical features: 5
#
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
catcol=df.dtypes[df.dtypes=='object'].index
catcol
# Out:
# Index(['Species'], dtype='object')

# %% [markdown]
# # 7. Summerize numerical variables

# %%
df[numcol].describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Correlation
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
#Visualizing the correlation using heatmap
fig=plt.figure(figsize=(15,9))
sns.heatmap(df.corr(),cmap='Blues',annot=True);

# %% [markdown]
# # 9.Obtain distribution of data of various columns

# %%
#Obtaining the distribution of data of various columns
fig,axes=plt.subplots(2,2,figsize=(16,9))
axes[0,0].set_title('Distribution of sepal width')
axes[0,0].hist(df['SepalWidthCm'],bins=5)
axes[0,1].set_title('Distribution of sepal length')
axes[0,1].hist(df['SepalLengthCm'],bins=7)
axes[1,0].set_title('Distribution of Petal width')
axes[1,0].hist(df['PetalWidthCm'],bins=5)
axes[1,1].set_title('Distribution of petal length')
axes[1,1].hist(df['PetalLengthCm'],bins=6)
# Out:
# (array([50.,  0., 11., 43., 35., 11.]),
#  array([1.        , 1.98333333, 2.96666667, 3.95      , 4.93333333,
#         5.91666667, 6.9       ]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# # 10.Perform univariate analysis

# %%
#Petal Width
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"PetalWidthCm").add_legend()
# Out:
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#Petal Length
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"PetalLengthCm").add_legend()
# Out:
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#Sepal Length
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"SepalLengthCm").add_legend()
# Out:
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#Sepal Width
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"SepalWidthCm").add_legend()
# Out:
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\GPT BGK\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
fig,axes = plt.subplots(2,2,figsize=(16,9))
sns.boxplot(y='PetalWidthCm',x="Species",data=df,orient='v', ax=axes[0,0])
sns.boxplot(y='PetalLengthCm',x="Species",data=df, ax=axes[0,1])
sns.boxplot(y='SepalLengthCm',x="Species",data=df, ax=axes[1,0])
sns.boxplot(y='SepalWidthCm',x="Species",data=df, ax=axes[1,1])
plt.show()

# %%
fig,axes = plt.subplots(2,2,figsize=(16,9))
sns.violinplot(y='PetalWidthCm',x="Species",data=df,orient='v', ax=axes[0,0])
sns.violinplot(y='PetalLengthCm',x="Species",data=df, ax=axes[0,1])
sns.violinplot(y='SepalLengthCm',x="Species",data=df, ax=axes[1,0])
sns.violinplot(y='SepalWidthCm',x="Species",data=df, ax=axes[1,1])
plt.show()
